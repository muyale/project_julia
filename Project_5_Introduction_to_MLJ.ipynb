# %%
import DataFrames
import CSV
import Plots

# %%
using DataFrames
using CSV
df = DataFrame(CSV.File("C:/Datasets/Insurance/Train_Data.csv"))
# Out:
# 3630×7 DataFrame
#   Row │ age      sex      bmi      smoker   region     children  charges
#       │ Float64  String7  Float64  String3  String15   Int64     Float64
# ──────┼───────────────────────────────────────────────────────────────────
#     1 │ 21.0     male     25.745   no       northeast         2   3279.87
#     2 │ 36.977   female   25.7442  yes      southeast         3  21454.5
#     3 │ 18.0     male     30.03    no       southeast         1   1720.35
#     4 │ 37.0     male     30.6769  no       northeast         3   6801.44
#     5 │ 58.0     male     32.01    no       southeast         1  11946.6
#     6 │ 46.0     male     26.62    no       southeast         1   7742.11
#     7 │ 25.2217  male     31.1926  no       northeast         4  21736.3
#     8 │ 29.4864  female   24.2226  no       northwest         2   4916.95
#     9 │ 26.5205  male     25.0657  no       southwest         5   5515.81
# ...

# %%
using Plots
x= df.bmi
y= df.age
scatter(x,y)

# %%
using Plots
histogram(df.age)

# %%
describe(df)
# Out:
# 7×7 DataFrame
#  Row │ variable  mean     min        median   max        nmissing  eltype
#      │ Symbol    Union…   Any        Union…   Any        Int64     DataType
# ─────┼──────────────────────────────────────────────────────────────────────
#    1 │ age       38.887   18.0       39.1709  64.0              0  Float64
#    2 │ sex                female              male              0  String7
#    3 │ bmi       30.6297  15.96      30.2     53.13             0  Float64
#    4 │ smoker             no                  yes               0  String3
#    5 │ region             northeast           southwest         0  String15
#    6 │ children  2.50358  0          3.0      5                 0  Int64
#    7 │ charges   12784.8  1121.87    9443.81  63770.4           0  Float64

# %%
a = 10
for i in range(0,a)
    print(a)
    a +=1
end
# Out:
# 1011121314151617181920

# %% [markdown]
# # INTRODUCTION TO MLJ

# %%
import MLJ

# %%
x= df.age
y = df.charges
# Out:
# 3630-element Vector{Float64}:
#   3279.86855
#  21454.494238637613
#   1720.3537
#   6801.437541833969
#  11946.6259
#   7742.1098
#  21736.32814453227
#   4916.953064777066
#   5515.809345071162
#  17009.334987374503
#  38433.5242957452
#   8549.13715464568
#  16099.36761714954
#      ⋮
#   4260.744000000001
#   6777.43023051541
#   6653.7886
#   9610.956358937623
#  21806.18160854768
#   2755.02095
#  10381.4787
#  10987.32496389396
#  11735.84435183786
#  10602.385
#   8976.140451535042
#   7027.698968230091

# %%
models()
#Listing all of the available packages
# Out:
# 200-element Vector{NamedTuple{(:name, :package_name, :is_supervised, :abstract_type, :deep_properties, :docstring, :fit_data_scitype, :human_name, :hyperparameter_ranges, :hyperparameter_types, :hyperparameters, :implemented_methods, :inverse_transform_scitype, :is_pure_julia, :is_wrapper, :iteration_parameter, :load_path, :package_license, :package_url, :package_uuid, :predict_scitype, :prediction_type, :reporting_operations, :reports_feature_importances, :supports_class_weights, :supports_online, :supports_training_losses, :supports_weights, :transform_scitype, :input_scitype, :target_scitype, :output_scitype)}}:
#  (name = ABODDetector, package_name = OutlierDetectionNeighbors, ... )
#  (name = ABODDetector, package_name = OutlierDetectionPython, ... )
#  (name = ARDRegressor, package_name = ScikitLearn, ... )
#  (name = AdaBoostClassifier, package_name = ScikitLearn, ... )
#  (name = AdaBoostRegressor, package_name = ScikitLearn, ... )
# ...

# %%
#Listing all of the supervised julia models
models(x -> x.is_supervised && x.is_pure_julia)
# Out:
# 62-element Vector{NamedTuple{(:name, :package_name, :is_supervised, :abstract_type, :deep_properties, :docstring, :fit_data_scitype, :human_name, :hyperparameter_ranges, :hyperparameter_types, :hyperparameters, :implemented_methods, :inverse_transform_scitype, :is_pure_julia, :is_wrapper, :iteration_parameter, :load_path, :package_license, :package_url, :package_uuid, :predict_scitype, :prediction_type, :reporting_operations, :reports_feature_importances, :supports_class_weights, :supports_online, :supports_training_losses, :supports_weights, :transform_scitype, :input_scitype, :target_scitype, :output_scitype)}}:
#  (name = AdaBoostStumpClassifier, package_name = DecisionTree, ... )
#  (name = BayesianLDA, package_name = MultivariateStats, ... )
#  (name = BayesianSubspaceLDA, package_name = MultivariateStats, ... )
#  (name = ConstantClassifier, package_name = MLJModels, ... )
#  (name = ConstantRegressor, package_name = MLJModels, ... )
# ...

# %%
 models(matching(x,y))
# To get models matching our inputs and targets
# Out:
# NamedTuple{(:name, :package_name, :is_supervised, :abstract_type, :deep_properties, :docstring, :fit_data_scitype, :human_name, :hyperparameter_ranges, :hyperparameter_types, :hyperparameters, :implemented_methods, :inverse_transform_scitype, :is_pure_julia, :is_wrapper, :iteration_parameter, :load_path, :package_license, :package_url, :package_uuid, :predict_scitype, :prediction_type, :reporting_operations, :reports_feature_importances, :supports_class_weights, :supports_online, :supports_training_losses, :supports_weights, :transform_scitype, :input_scitype, :target_scitype, :output_scitype)}[]

# %%
ridge = @load RidgeRegressor
pkg= ScikitLearn
# Out:
# [ Info: For silent loading, specify `verbosity=0`.
# ArgumentError: Ambiguous model type name. Use pkg=... .
# The model RidgeRegressor is provided by these packages:
#  ["ScikitLearn", "MLJLinearModels", "MultivariateStats"].
#
#
# Stacktrace:
#  [1] handle(name::String; pkg::Nothing, interactive::Bool)
#    @ MLJModels C:\Users\EDGAR MUYALE DAVIES\.julia\packages\MLJModels\gJoE1\src\model_search.jl:111
#  [2] info(name::String; kwargs::Base.Pairs{Symbol, Union{Nothing, Bool}, Tuple{Symbol, Symbol}, NamedTuple{(:pkg, :interactive), Tuple{Nothing, Bool}}})
#    @ MLJModels C:\Users\EDGAR MUYALE DAVIES\.julia\packages\MLJModels\gJoE1\src\model_search.jl:154
#  [3] top-level scope
#    @ C:\Users\EDGAR MUYALE DAVIES\.julia\packages\MLJModels\gJoE1\src\loading.jl:160
