# %%
using CSV
using DataFrames
using Plots

# %%
# Reading csv files
using CSV 
churn = DataFrame(CSV.File("C:\\Datasets\\Churn_for_customers\\Churn_Modelling.csv"))
# Out:
# 10000×14 DataFrame
#    Row │ RowNumber  CustomerId  Surname      CreditScore  Geography  Gender    ⋯
#        │ Int64      Int64       String31     Int64        String7    String7   ⋯
# ───────┼────────────────────────────────────────────────────────────────────────
#      1 │         1    15634602  Hargrave             619  France     Female    ⋯
#      2 │         2    15647311  Hill                 608  Spain      Female
#      3 │         3    15619304  Onio                 502  France     Female
#      4 │         4    15701354  Boni                 699  France     Female
#      5 │         5    15737888  Mitchell             850  Spain      Female    ⋯
#      6 │         6    15574012  Chu                  645  Spain      Male
#      7 │         7    15592531  Bartlett             822  France     Male
#      8 │         8    15656148  Obinna               376  Germany    Female
#      9 │         9    15792365  He                   501  France     Male      ⋯
# ...

# %%
typeof(churn)
# Out:
# DataFrame

# %%
# printing columns
names(churn)
# Out:
# 14-element Vector{String}:
#  "RowNumber"
#  "CustomerId"
#  "Surname"
#  "CreditScore"
#  "Geography"
#  "Gender"
#  "Age"
#  "Tenure"
#  "Balance"
#  "NumOfProducts"
#  "HasCrCard"
#  "IsActiveMember"
#  "EstimatedSalary"
#  "Exited"

# %%
# Checking on the total number of rows and columns
size(churn)
# Out:
# (10000, 14)

# %%
using DataFrames
DataFrames.describe(churn)
# Out:
# 14×7 DataFrame
#  Row │ variable         mean       min       median     max        nmissing  e ⋯
#      │ Symbol           Union…     Any       Union…     Any        Int64     D ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ RowNumber        5000.5     1         5000.5     10000             0  I ⋯
#    2 │ CustomerId       1.56909e7  15565701  1.56907e7  15815690          0  I
#    3 │ Surname                     Abazu                Zuyeva            0  S
#    4 │ CreditScore      650.529    350       652.0      850               0  I
#    5 │ Geography                   France               Spain             0  S ⋯
#    6 │ Gender                      Female               Male              0  S
#    7 │ Age              38.9218    18        37.0       92                0  I
#    8 │ Tenure           5.0128     0         5.0        10                0  I
# ...

# %%
churn[:,3]
# Out:
# 10000-element Vector{String31}:
#  "Hargrave"
#  "Hill"
#  "Onio"
#  "Boni"
#  "Mitchell"
#  "Chu"
#  "Bartlett"
#  "Obinna"
#  "He"
#  "H?"
#  "Bearce"
#  "Andrews"
#  "Kay"
#  ⋮
#  "Pirozzi"
#  "McMillan"
#  "Nkemakonam"
#  "Ajuluchukwu"
#  "Chukwualuka"
#  "Rahman"
#  "Wood"
#  "Obijiaku"
#  "Johnstone"
#  "Liu"
#  "Sabbatini"
#  "Walker"

# %%
churn[:,[1,2,3]]
# Out:
# 10000×3 DataFrame
#    Row │ RowNumber  CustomerId  Surname
#        │ Int64      Int64       String31
# ───────┼────────────────────────────────────
#      1 │         1    15634602  Hargrave
#      2 │         2    15647311  Hill
#      3 │         3    15619304  Onio
#      4 │         4    15701354  Boni
#      5 │         5    15737888  Mitchell
#      6 │         6    15574012  Chu
#      7 │         7    15592531  Bartlett
#      8 │         8    15656148  Obinna
#      9 │         9    15792365  He
#     10 │        10    15592389  H?
#     11 │        11    15767821  Bearce
#    ⋮   │     ⋮          ⋮            ⋮
#   9991 │      9991    15798964  Nkemakonam
#   9992 │      9992    15769959  Ajuluchukwu
#   9993 │      9993    15657105  Chukwualuka
#   9994 │      9994    15569266  Rahman
#   9995 │      9995    15719294  Wood
#   9996 │      9996    15606229  Obijiaku
#   9997 │      9997    15569892  Johnstone
#   9998 │      9998    15584532  Liu
# ...

# %%
histogram(churn.Age,title="The Distribution of Customer Age")

# %%
scatter(churn.Age,ylabel="age",xlabel="total",title="ScatterPlot for Age")
